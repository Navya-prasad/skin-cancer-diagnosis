# %% [markdown]
# <a href="https://colab.research.google.com/github/Navya-prasad/skin-cancer-diagnosis/blob/main/Copy_of_Skin_ResNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# needed to import dataset from google drive into colab
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
cd gdrive
# Out:
# /content/gdrive

# %%
# !ls
# Out:
# MyDrive

# %%
cd MyDrive
# Out:
# /content/gdrive/MyDrive

# %%
# Import all the Dependencies
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import roc_curve, roc_auc_score
from tensorflow.keras.applications import ResNet50

# %%
# Set all the Constants
BATCH_SIZE = 32
IMAGE_SIZE = 224
CHANNELS = 3
EPOCHS = 100

# %%
# !ls
# Out:
#  amity		    Football		     skinalexnet.h5		      skinMobileNetV2.h5
# 'Colab Notebooks'  'Guest lecture photos '   skin_cancer_svm_classifier.pkl   skinResNet.h5

# %%
# Import dataset
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/gdrive/MyDrive/Colab Notebooks/cancer-full-dataset",
    seed=123,
    shuffle=True,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE
)

class_names = dataset.class_names
class_names
# Out:
# Found 1968 files belonging to 2 classes.
# ['benign', 'malignant']

# %%
# Function to Split Dataset
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1

    ds_size = len(ds)

    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)

    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)

    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
# Cache, Shuffle, and Prefetch the Dataset
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# Building the Model
# Creating a new Layer for Resizing and Normalization
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.experimental.preprocessing.Rescaling(1./244),
])

# %%
# Data Augmentation
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
# Applying Data Augmentation to Train Dataset
train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# Model Architecture
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS))

n_classes = 2

model = models.Sequential([
    resize_and_rescale,
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(n_classes, activation='softmax')
])

model.build((None, IMAGE_SIZE, IMAGE_SIZE, CHANNELS))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 2)                 4098
#
# =================================================================
# Total params: 23591810 (90.00 MB)
# Trainable params: 23538690 (89.79 MB)
# Non-trainable params: 53120 (207.50 KB)
# _________________________________________________________________

# %%
# Compiling the Model
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=1,
    epochs=EPOCHS,
)
# Out:
# Epoch 1/100
# 49/49 [==============================] - 277s 835ms/step - loss: 0.8095 - accuracy: 0.7223 - val_loss: 1175.2981 - val_accuracy: 0.2273
# Epoch 2/100
# 49/49 [==============================] - 17s 353ms/step - loss: 0.6364 - accuracy: 0.7378 - val_loss: 0.5568 - val_accuracy: 0.7727
# Epoch 3/100
# 49/49 [==============================] - 18s 372ms/step - loss: 0.6326 - accuracy: 0.7584 - val_loss: 668.3881 - val_accuracy: 0.2273
# Epoch 4/100
# 49/49 [==============================] - 18s 357ms/step - loss: 0.5779 - accuracy: 0.7597 - val_loss: 0.5398 - val_accuracy: 0.7727
# Epoch 5/100
# 49/49 [==============================] - 19s 375ms/step - loss: 0.5581 - accuracy: 0.7622 - val_loss: 0.6115 - val_accuracy: 0.7727
# Epoch 6/100
# 49/49 [==============================] - 18s 367ms/step - loss: 0.5301 - accuracy: 0.7680 - val_loss: 0.5812 - val_accuracy: 0.7727
# Epoch 7/100
# 49/49 [==============================] - 18s 358ms/step - loss: 0.6044 - accuracy: 0.7655 - val_loss: 0.5814 - val_accuracy: 0.7727
# Epoch 8/100
# 49/49 [==============================] - 18s 359ms/step - loss: 0.5393 - accuracy: 0.7796 - val_loss: 0.5916 - val_accuracy: 0.7727
# Epoch 9/100
# 49/49 [==============================] - 18s 364ms/step - loss: 0.5148 - accuracy: 0.7751 - val_loss: 0.5634 - val_accuracy: 0.7727
# Epoch 10/100
# 49/49 [==============================] - 18s 359ms/step - loss: 0.5142 - accuracy: 0.7771 - val_loss: 0.5371 - val_accuracy: 0.7727
# Epoch 11/100
# 49/49 [==============================] - 18s 367ms/step - loss: 0.5060 - accuracy: 0.7835 - val_loss: 0.5668 - val_accuracy: 0.7727
# Epoch 12/100
# 49/49 [==============================] - 18s 362ms/step - loss: 0.4983 - accuracy: 0.7848 - val_loss: 0.5585 - val_accuracy: 0.7727
# Epoch 13/100
# 49/49 [==============================] - 18s 362ms/step - loss: 0.4718 - accuracy: 0.7887 - val_loss: 0.5881 - val_accuracy: 0.7727
# Epoch 14/100
# 49/49 [==============================] - 18s 365ms/step - loss: 0.4666 - accuracy: 0.7893 - val_loss: 0.5968 - val_accuracy: 0.7727
# Epoch 15/100
# 49/49 [==============================] - 18s 371ms/step - loss: 0.4765 - accuracy: 0.7880 - val_loss: 0.5753 - val_accuracy: 0.7727
# Epoch 16/100
# 49/49 [==============================] - 19s 373ms/step - loss: 0.4588 - accuracy: 0.7932 - val_loss: 0.5489 - val_accuracy: 0.7727
# Epoch 17/100
# 49/49 [==============================] - 18s 359ms/step - loss: 0.4704 - accuracy: 0.7932 - val_loss: 0.6000 - val_accuracy: 0.7727
# Epoch 18/100
# 49/49 [==============================] - 18s 359ms/step - loss: 0.4728 - accuracy: 0.7977 - val_loss: 3.1340 - val_accuracy: 0.7727
# Epoch 19/100
# 49/49 [==============================] - 18s 362ms/step - loss: 0.4634 - accuracy: 0.8061 - val_loss: 0.4870 - val_accuracy: 0.7955
# Epoch 20/100
# 49/49 [==============================] - 18s 372ms/step - loss: 0.4575 - accuracy: 0.8035 - val_loss: 0.5130 - val_accuracy: 0.7898
# Epoch 21/100
# 49/49 [==============================] - 18s 358ms/step - loss: 0.4507 - accuracy: 0.7970 - val_loss: 0.6466 - val_accuracy: 0.7841
# Epoch 22/100
# 49/49 [==============================] - 18s 370ms/step - loss: 0.4404 - accuracy: 0.8099 - val_loss: 0.4375 - val_accuracy: 0.8182
# Epoch 23/100
# 49/49 [==============================] - 18s 364ms/step - loss: 0.4265 - accuracy: 0.8086 - val_loss: 0.5869 - val_accuracy: 0.7670
# Epoch 24/100
# 49/49 [==============================] - 18s 360ms/step - loss: 0.4274 - accuracy: 0.8183 - val_loss: 1.8648 - val_accuracy: 0.7841
# Epoch 25/100
# 49/49 [==============================] - 18s 359ms/step - loss: 0.4309 - accuracy: 0.8131 - val_loss: 0.4385 - val_accuracy: 0.8409
# Epoch 26/100
# 49/49 [==============================] - 18s 367ms/step - loss: 0.3998 - accuracy: 0.8235 - val_loss: 0.5064 - val_accuracy: 0.8580
# Epoch 27/100
# 49/49 [==============================] - 18s 365ms/step - loss: 0.4038 - accuracy: 0.8241 - val_loss: 0.5322 - val_accuracy: 0.8068
# Epoch 28/100
# 49/49 [==============================] - 18s 373ms/step - loss: 0.3802 - accuracy: 0.8389 - val_loss: 0.5452 - val_accuracy: 0.8125
# Epoch 29/100
# 49/49 [==============================] - 18s 356ms/step - loss: 0.3902 - accuracy: 0.8318 - val_loss: 0.5750 - val_accuracy: 0.7557
# Epoch 30/100
# 49/49 [==============================] - 18s 362ms/step - loss: 0.3863 - accuracy: 0.8286 - val_loss: 0.5146 - val_accuracy: 0.7955
# Epoch 31/100
# 49/49 [==============================] - 18s 370ms/step - loss: 0.3824 - accuracy: 0.8312 - val_loss: 0.4707 - val_accuracy: 0.8352
# Epoch 32/100
# 49/49 [==============================] - 18s 357ms/step - loss: 0.3752 - accuracy: 0.8312 - val_loss: 0.5389 - val_accuracy: 0.7898
# Epoch 33/100
# 49/49 [==============================] - 18s 358ms/step - loss: 0.3700 - accuracy: 0.8396 - val_loss: 2.2247 - val_accuracy: 0.7955
# Epoch 34/100
# 49/49 [==============================] - 18s 372ms/step - loss: 0.4197 - accuracy: 0.8222 - val_loss: 1.0531 - val_accuracy: 0.7273
# Epoch 35/100
# 49/49 [==============================] - 18s 363ms/step - loss: 0.3954 - accuracy: 0.8312 - val_loss: 0.4501 - val_accuracy: 0.8239
# Epoch 36/100
# 49/49 [==============================] - 18s 358ms/step - loss: 0.3540 - accuracy: 0.8466 - val_loss: 0.7052 - val_accuracy: 0.8125
# Epoch 37/100
# 49/49 [==============================] - 18s 364ms/step - loss: 0.3539 - accuracy: 0.8460 - val_loss: 0.9314 - val_accuracy: 0.8068
# Epoch 38/100
# 49/49 [==============================] - 18s 367ms/step - loss: 0.3470 - accuracy: 0.8524 - val_loss: 2.0250 - val_accuracy: 0.7784
# Epoch 39/100
# 49/49 [==============================] - 18s 366ms/step - loss: 0.3530 - accuracy: 0.8537 - val_loss: 0.5354 - val_accuracy: 0.8125
# Epoch 40/100
# 49/49 [==============================] - 18s 366ms/step - loss: 0.3531 - accuracy: 0.8466 - val_loss: 0.6396 - val_accuracy: 0.7898
# Epoch 41/100
# 49/49 [==============================] - 18s 368ms/step - loss: 0.3604 - accuracy: 0.8531 - val_loss: 0.9611 - val_accuracy: 0.8352
# Epoch 42/100
# 49/49 [==============================] - 18s 364ms/step - loss: 0.3365 - accuracy: 0.8557 - val_loss: 0.8074 - val_accuracy: 0.8295
# Epoch 43/100
# 49/49 [==============================] - 18s 368ms/step - loss: 0.3188 - accuracy: 0.8615 - val_loss: 0.6279 - val_accuracy: 0.7955
# Epoch 44/100
# 49/49 [==============================] - 18s 364ms/step - loss: 0.3506 - accuracy: 0.8531 - val_loss: 0.6638 - val_accuracy: 0.6364
# Epoch 45/100
# 49/49 [==============================] - 18s 361ms/step - loss: 0.3586 - accuracy: 0.8531 - val_loss: 0.6839 - val_accuracy: 0.8011
# Epoch 46/100
# 49/49 [==============================] - 18s 363ms/step - loss: 0.3057 - accuracy: 0.8737 - val_loss: 0.6642 - val_accuracy: 0.6989
# Epoch 47/100
# 49/49 [==============================] - 18s 365ms/step - loss: 0.2815 - accuracy: 0.8898 - val_loss: 0.7017 - val_accuracy: 0.7102
# Epoch 48/100
# 49/49 [==============================] - 18s 363ms/step - loss: 0.3278 - accuracy: 0.8653 - val_loss: 1.2142 - val_accuracy: 0.7727
# Epoch 49/100
# 49/49 [==============================] - 18s 362ms/step - loss: 0.3513 - accuracy: 0.8396 - val_loss: 0.6052 - val_accuracy: 0.7500
# Epoch 50/100
# 49/49 [==============================] - 18s 360ms/step - loss: 0.2966 - accuracy: 0.8802 - val_loss: 1.6251 - val_accuracy: 0.7614
# Epoch 51/100
# 49/49 [==============================] - 18s 363ms/step - loss: 0.2683 - accuracy: 0.8937 - val_loss: 0.7416 - val_accuracy: 0.6932
# Epoch 52/100
# 49/49 [==============================] - 18s 364ms/step - loss: 0.2725 - accuracy: 0.8898 - val_loss: 1.3704 - val_accuracy: 0.8182
# Epoch 53/100
# 49/49 [==============================] - 19s 374ms/step - loss: 0.2615 - accuracy: 0.8956 - val_loss: 0.4964 - val_accuracy: 0.7955
# Epoch 54/100
# 49/49 [==============================] - 19s 377ms/step - loss: 0.2667 - accuracy: 0.8879 - val_loss: 1.9384 - val_accuracy: 0.8011
# Epoch 55/100
# 49/49 [==============================] - 18s 361ms/step - loss: 0.2386 - accuracy: 0.8982 - val_loss: 0.5436 - val_accuracy: 0.8977
# Epoch 56/100
# 49/49 [==============================] - 19s 393ms/step - loss: 0.2362 - accuracy: 0.9046 - val_loss: 1.7299 - val_accuracy: 0.7614
# Epoch 57/100
# 49/49 [==============================] - 18s 367ms/step - loss: 0.2565 - accuracy: 0.8976 - val_loss: 0.9268 - val_accuracy: 0.7670
# Epoch 58/100
# 49/49 [==============================] - 18s 362ms/step - loss: 0.2495 - accuracy: 0.8956 - val_loss: 0.8930 - val_accuracy: 0.8295
# Epoch 59/100
# 49/49 [==============================] - 18s 371ms/step - loss: 0.2152 - accuracy: 0.9079 - val_loss: 0.5695 - val_accuracy: 0.8466
# Epoch 60/100
# 49/49 [==============================] - 18s 367ms/step - loss: 0.2084 - accuracy: 0.9143 - val_loss: 1.3307 - val_accuracy: 0.7841
# Epoch 61/100
# 49/49 [==============================] - 19s 379ms/step - loss: 0.2890 - accuracy: 0.8937 - val_loss: 1.4232 - val_accuracy: 0.8068
# Epoch 62/100
# 49/49 [==============================] - 18s 362ms/step - loss: 0.2056 - accuracy: 0.9162 - val_loss: 0.3589 - val_accuracy: 0.8864
# Epoch 63/100
# 49/49 [==============================] - 18s 363ms/step - loss: 0.2103 - accuracy: 0.9066 - val_loss: 1.2877 - val_accuracy: 0.6761
# Epoch 64/100
# 49/49 [==============================] - 18s 364ms/step - loss: 0.2649 - accuracy: 0.8943 - val_loss: 0.9904 - val_accuracy: 0.7670
# Epoch 65/100
# 49/49 [==============================] - 18s 359ms/step - loss: 0.2209 - accuracy: 0.9053 - val_loss: 0.7471 - val_accuracy: 0.7841
# Epoch 66/100
# 49/49 [==============================] - 18s 371ms/step - loss: 0.1854 - accuracy: 0.9272 - val_loss: 2.2201 - val_accuracy: 0.7841
# Epoch 67/100
# 49/49 [==============================] - 19s 387ms/step - loss: 0.1702 - accuracy: 0.9317 - val_loss: 0.4006 - val_accuracy: 0.8466
# Epoch 68/100
# 49/49 [==============================] - 18s 362ms/step - loss: 0.1685 - accuracy: 0.9291 - val_loss: 0.8635 - val_accuracy: 0.7955
# Epoch 69/100
# 49/49 [==============================] - 18s 370ms/step - loss: 0.2027 - accuracy: 0.9137 - val_loss: 1.4080 - val_accuracy: 0.8011
# Epoch 70/100
# 49/49 [==============================] - 18s 363ms/step - loss: 0.1763 - accuracy: 0.9253 - val_loss: 1.7680 - val_accuracy: 0.7898
# Epoch 71/100
# 49/49 [==============================] - 18s 366ms/step - loss: 0.1478 - accuracy: 0.9381 - val_loss: 0.5959 - val_accuracy: 0.8409
# Epoch 72/100
# 49/49 [==============================] - 18s 364ms/step - loss: 0.1785 - accuracy: 0.9265 - val_loss: 1.7597 - val_accuracy: 0.7898
# Epoch 73/100
# 49/49 [==============================] - 18s 364ms/step - loss: 0.1505 - accuracy: 0.9420 - val_loss: 0.7785 - val_accuracy: 0.8466
# Epoch 74/100
# 49/49 [==============================] - 18s 358ms/step - loss: 0.1529 - accuracy: 0.9375 - val_loss: 0.4608 - val_accuracy: 0.8409
# Epoch 75/100
# 49/49 [==============================] - 18s 366ms/step - loss: 0.1486 - accuracy: 0.9439 - val_loss: 3.2107 - val_accuracy: 0.7102
# Epoch 76/100
# 49/49 [==============================] - 18s 364ms/step - loss: 0.1628 - accuracy: 0.9388 - val_loss: 0.7963 - val_accuracy: 0.6193
# Epoch 77/100
# 49/49 [==============================] - 18s 366ms/step - loss: 0.1448 - accuracy: 0.9375 - val_loss: 2.0886 - val_accuracy: 0.8182
# Epoch 78/100
# 49/49 [==============================] - 18s 362ms/step - loss: 0.1391 - accuracy: 0.9433 - val_loss: 5.0918 - val_accuracy: 0.7614
# Epoch 79/100
# 49/49 [==============================] - 18s 371ms/step - loss: 0.1228 - accuracy: 0.9549 - val_loss: 1.0990 - val_accuracy: 0.8182
# Epoch 80/100
# 49/49 [==============================] - 19s 376ms/step - loss: 0.1270 - accuracy: 0.9530 - val_loss: 0.5222 - val_accuracy: 0.8466
# Epoch 81/100
# 49/49 [==============================] - 18s 363ms/step - loss: 0.1333 - accuracy: 0.9485 - val_loss: 1.1965 - val_accuracy: 0.7898
# Epoch 82/100
# 49/49 [==============================] - 18s 375ms/step - loss: 0.1516 - accuracy: 0.9388 - val_loss: 0.5812 - val_accuracy: 0.8239
# Epoch 83/100
# 49/49 [==============================] - 18s 363ms/step - loss: 0.1681 - accuracy: 0.9330 - val_loss: 2.7027 - val_accuracy: 0.7614
# Epoch 84/100
# 49/49 [==============================] - 18s 362ms/step - loss: 0.1216 - accuracy: 0.9504 - val_loss: 0.7287 - val_accuracy: 0.7898
# Epoch 85/100
# 49/49 [==============================] - 18s 371ms/step - loss: 0.1005 - accuracy: 0.9620 - val_loss: 0.7731 - val_accuracy: 0.7841
# Epoch 86/100
# 49/49 [==============================] - 18s 359ms/step - loss: 0.1493 - accuracy: 0.9536 - val_loss: 1.0308 - val_accuracy: 0.8295
# Epoch 87/100
# 49/49 [==============================] - 18s 374ms/step - loss: 0.1905 - accuracy: 0.9265 - val_loss: 1.7963 - val_accuracy: 0.7557
# Epoch 88/100
# 49/49 [==============================] - 18s 360ms/step - loss: 0.1357 - accuracy: 0.9452 - val_loss: 6.9029 - val_accuracy: 0.8580
# Epoch 89/100
# 49/49 [==============================] - 18s 366ms/step - loss: 0.0938 - accuracy: 0.9639 - val_loss: 0.8681 - val_accuracy: 0.8068
# Epoch 90/100
# 49/49 [==============================] - 18s 368ms/step - loss: 0.0697 - accuracy: 0.9736 - val_loss: 0.6021 - val_accuracy: 0.7898
# Epoch 91/100
# 49/49 [==============================] - 18s 362ms/step - loss: 0.0868 - accuracy: 0.9710 - val_loss: 0.9333 - val_accuracy: 0.8523
# Epoch 92/100
# 49/49 [==============================] - 18s 369ms/step - loss: 0.1049 - accuracy: 0.9626 - val_loss: 0.9514 - val_accuracy: 0.7273
# Epoch 93/100
# 49/49 [==============================] - 19s 376ms/step - loss: 0.1245 - accuracy: 0.9588 - val_loss: 1.1326 - val_accuracy: 0.7557
# Epoch 94/100
# 49/49 [==============================] - 18s 357ms/step - loss: 0.1095 - accuracy: 0.9568 - val_loss: 1.1271 - val_accuracy: 0.7045
# Epoch 95/100
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0950 - accuracy: 0.9729 - val_loss: 2.7142 - val_accuracy: 0.7159
# Epoch 96/100
# 49/49 [==============================] - 18s 368ms/step - loss: 0.0707 - accuracy: 0.9749 - val_loss: 3.8819 - val_accuracy: 0.7500
# Epoch 97/100
# 49/49 [==============================] - 18s 362ms/step - loss: 0.1039 - accuracy: 0.9588 - val_loss: 3.0898 - val_accuracy: 0.7784
# Epoch 98/100
# 49/49 [==============================] - 18s 354ms/step - loss: 0.1623 - accuracy: 0.9356 - val_loss: 1.6612 - val_accuracy: 0.7670
# Epoch 99/100
# 49/49 [==============================] - 18s 365ms/step - loss: 0.1250 - accuracy: 0.9530 - val_loss: 0.6400 - val_accuracy: 0.8239
# Epoch 100/100
# 49/49 [==============================] - 18s 364ms/step - loss: 0.0523 - accuracy: 0.9826 - val_loss: 1.2947 - val_accuracy: 0.7670

# %%
# Plotting the Accuracy and Loss Curves
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 3))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 100, 'steps': 49}

# %%
# Run prediction on a sample image
def predict(model, img):
    img_array = tf.expand_dims(img, 0)
    img_array = tf.keras.applications.resnet50.preprocess_input(img_array)

    predictions = model.predict(img_array)
    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * np.max(predictions[0]), 2)

    return predicted_class, confidence

plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))

        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]]

        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")

        plt.axis("off")
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step

# %%
# Evaluate the model on the test dataset
test_loss, test_accuracy = model.evaluate(test_ds, verbose=1)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 7/7 [==============================] - 1s 101ms/step - loss: 1.3634 - accuracy: 0.7634
# Test Loss: 1.3634451627731323
# Test Accuracy: 0.7633928656578064

# %%
scores = model.evaluate(test_ds)
# Out:
# 7/7 [==============================] - 1s 98ms/step - loss: 1.3634 - accuracy: 0.7634

# %%
# Plotting the Accuracy Score
plt.figure(figsize=(6, 4))
plt.bar(["Accuracy"], [scores[1]], color='blue')
plt.ylim(0, 1)  # Set the y-axis limit from 0 to 1
plt.xlabel("Metrics")
plt.ylabel("Accuracy")
plt.title("Accuracy Score")
plt.show()

# %%
# Plotting the Training Accuracy Score and Validation Accuracy Score
plt.figure(figsize=(8, 4))
metrics = ["Training Accuracy", "Validation Accuracy"]
accuracy_scores = [acc[-1], val_acc[-1]]

plt.bar(metrics, accuracy_scores, color=['blue', 'orange'])
plt.ylim(0, 1)  # Set the y-axis limit from 0 to 1
plt.xlabel("Metrics")
plt.ylabel("Accuracy")
plt.title("Accuracy Scores")
plt.show()

# %%
import itertools
# Printing Precision, Recall, and F1 Score
test_images = []
test_labels = []
predicted_labels = []

for images_batch, labels_batch in test_ds:
    test_images.extend(images_batch.numpy())
    test_labels.extend(labels_batch.numpy())
    batch_prediction = model.predict(images_batch)
    predicted_labels.extend(np.argmax(batch_prediction, axis=1))

test_labels = np.array(test_labels)
predicted_labels = np.array(predicted_labels)

precision = precision_score(test_labels, predicted_labels, average=None, zero_division=0)
recall = recall_score(test_labels, predicted_labels, average=None)
f1 = f1_score(test_labels, predicted_labels, average=None)

from sklearn.metrics import confusion_matrix

# Assuming you have your test labels (`test_labels`) and predicted labels (`predicted_labels`) as NumPy arrays

# Calculate the confusion matrix
cm = confusion_matrix(test_labels, predicted_labels)
TP = cm[1, 1]  # True Positives
FP = cm[1, 0]  # False Positives
TN = cm[0, 0]  # True Negatives
FN = cm[0, 1]  # False Negatives

print("True Positives (TP):", TP)
print("False Positives (FP):", FP)
print("True Negatives (TN):", TN)
print("False Negatives (FN):", FN)

# Optional: Plot the confusion matrix
def plot_confusion_matrix(cm, class_names=None, normalize=False, title=None, cmap=plt.cm.Blues):
    """
    Plots a confusion matrix with labels and normalization options.

    Args:
        cm (numpy.ndarray): Confusion matrix.
        class_names (list, optional): List of class names (default: None).
        normalize (bool, optional): Normalize confusion matrix (default: False).
        title (str, optional): Title for the confusion matrix plot (default: None).
        cmap (matplotlib.colors.Colormap, optional): Colormap for the plot (default: plt.cm.Blues).

    Returns:
        None
    """

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print("Confusion matrix")

    print(cm)

    plt.figure(figsize=(8, 6))  # Adjust figure size as needed

    if class_names is not None:
        tick_marks = np.arange(len(class_names))
        plt.xticks(tick_marks, class_names, rotation=45)
        plt.yticks(tick_marks, class_names)

    # Display heatmap
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.colorbar()

    # Text labels for each cell
    if normalize:
        fmt = '.2f'
    else:
        fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    if title is not None:
        plt.title(title)

    plt.tight_layout()
    plt.show()  # Customize as needed
plot_confusion_matrix(cm, class_names=["Negative", "Positive"], normalize=True, title="Normalized Confusion Matrix")
# Calculate Precision, Recall, and F1 Score
precision = precision_score(test_labels, predicted_labels, average=None, zero_division=0)
recall = recall_score(test_labels, predicted_labels, average=None)
f1 = f1_score(test_labels, predicted_labels, average=None)
# Print precision, recall, and F1-score
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1)
# Plotting the metrics
plt.figure(figsize=(10, 6))
x = np.arange(len(class_names))

plt.bar(x - 0.2, precision, width=0.2, label='Precision')
plt.bar(x, recall, width=0.2, label='Recall')
plt.bar(x + 0.2, f1, width=0.2, label='F1 Score')

plt.xticks(x, class_names, rotation=45)
plt.xlabel('Skin Cancer Detection ResNet50')
plt.ylabel('Score')
plt.title('Precision, Recall, and F1 Score')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# True Positives (TP): 25
# False Positives (FP): 37
# True Negatives (TN): 146
# False Negatives (FN): 16
# Normalized confusion matrix
# [[0.90123457 0.09876543]
#  [0.59677419 0.40322581]]
# Precision: [0.79781421 0.6097561 ]
# Recall: [0.90123457 0.40322581]
# F1-Score: [0.84637681 0.48543689]

# %%
# After evaluating the model on the test set
test_labels = []
predicted_probabilities = []

for images_batch, labels_batch in test_ds:
    test_labels.extend(labels_batch.numpy())
    batch_prediction = model.predict(images_batch)
    predicted_probabilities.extend(batch_prediction)

test_labels = np.array(test_labels)
predicted_probabilities = np.array(predicted_probabilities)

# Calculate the ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(test_labels, predicted_probabilities[:, 1])
auc_score = roc_auc_score(test_labels, predicted_probabilities[:, 1])

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC Curve (AUC = {:.2f})'.format(auc_score))
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# Print the AUC score
print('AUC Score:', auc_score)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# AUC Score: 0.7250099561927519

# %%
# Saving the Model
model.save("skinResNet.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
